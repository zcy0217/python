# %% [markdown]
# # 第一題
# 寫一程式，輸入 n 個整數，輸出 n 個整數的總和。
#
# 請完整呈現下面兩張圖
#
# p.s.請不要直接print答案

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
time = int(input("輸入一個正整數:"))
total = 0
word = ""
for i in range(time):
    number = input(f"輸入第{i+1}的整數:")
    total+=int(number)
    word+=number+"+"
print(f"{word}\b={total}")
# Out:
# 輸入一個正整數:3
# 輸入第1的整數:1
# 輸入第2的整數:2
# 輸入第3的整數:3
# 1+2+3 = 6
