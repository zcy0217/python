# %% [markdown]
# # 第二題
# 阿明想要在中信館做出一顆巨大的聖誕樹在聖誕節的時候使用。他想用程式所學先模擬一個小的聖誕樹
# 所以!~請製作出下面的圖形

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
height = 9
stars = 1

for i in range(height):
    print((' ' * (height - i)) + ('@' * stars))
    stars += 2
for u in range(5):
  print((" "*(height-1))+"|#|")
# Out:
#          @
#         @@@
#        @@@@@
#       @@@@@@@
#      @@@@@@@@@
#     @@@@@@@@@@@
#    @@@@@@@@@@@@@
#   @@@@@@@@@@@@@@@
#  @@@@@@@@@@@@@@@@@
#         |#|
#         |#|
#         |#|
#         |#|
#         |#|
