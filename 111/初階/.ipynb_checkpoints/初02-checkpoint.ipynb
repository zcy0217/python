# %%
'''

寫一程式，輸入n個整數，輸出n個整數的總和。

請完整呈現下面的圖

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
time = int(input("請輸入欲累加的數量:"))
total = 0
word = ""
for i in range(time):
    number = input(f"輸入第{i+1}的整數:")
    total+=int(number)
    word+=number+"+"
print(f"{word}\b={total}")
# Out:
# 請輸入欲累加的數量:5
# 輸入第1的整數:1
# 輸入第2的整數:2
# 輸入第3的整數:3
# 輸入第4的整數:4
# 輸入第5的整數:5
# 1+2+3+4+5=15

# %%
#1102_1
